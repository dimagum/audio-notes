# %%
from audio_notes.evaluation.asr_metrics import calculate_asr_metrics

result = calculate_asr_metrics(
    reference="сегодня обсудили обучение модели на новых данных",
    hypothesis="сегодня обсудили обучение модели новых данных",
)

print(result)
# {'wer': 0.125, 'cer': ...}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from audio_notes.evaluation.asr_metrics import calculate_asr_metrics
#       2
#       3 result = calculate_asr_metrics(
#       4     reference="сегодня обсудили обучение модели на новых данных",
#
# ModuleNotFoundError: No module named 'audio_notes'
